# %%
import pandas as pd
data=pd.read_csv('57847.csv', sep=';',header=1)
data= data.values
arr_name=[]
arr_tot=[]
#print(data)

for  d in data:
    palabra=str(d[2])+""
    #print(d)
    if d[4]=="Ambos sexos" and palabra=="nan":
        numero=float((str(d[6])).replace(".",""))
        print(str(d[0])+" "+str(d[5])+" " +str(numero))
  #print (d)
# Out:
# 1. TOTAL PAÍSES (TODOS LOS CONTINENTES) Menos de 16 años 92133.0
# 1. TOTAL PAÍSES (TODOS LOS CONTINENTES) De 16 a 64 años 440367.0
# 1. TOTAL PAÍSES (TODOS LOS CONTINENTES) De 65 y más años 31216.0
# 2 TOTAL EUROPA Total grupos de edad 495004.0
# 2 TOTAL EUROPA Menos de 16 años 59442.0
# 2 TOTAL EUROPA De 16 a 64 años 30996.0
# 2 TOTAL EUROPA De 65 y más años 125602.0
# ALEMANIA Total grupos de edad 81971.0
# ALEMANIA Menos de 16 años 10113.0
# ALEMANIA De 16 a 64 años 53513.0
# ALEMANIA De 65 y más años 18345.0
# ANDORRA Total grupos de edad 19515.0
# ANDORRA Menos de 16 años 8600.0
# ANDORRA De 16 a 64 años 13085.0
# ANDORRA De 65 y más años 557.0
# AUSTRIA Total grupos de edad 3924.0
# AUSTRIA Menos de 16 años 2600.0
# AUSTRIA De 16 a 64 años 3424.0
# AUSTRIA De 65 y más años 2400.0
# BÉLGICA Total grupos de edad 32514.0
# BÉLGICA Menos de 16 años 5555.0
# BÉLGICA De 16 a 64 años 17453.0
# BÉLGICA De 65 y más años 9506.0
# DINAMARCA Total grupos de edad 357.0
# ...
