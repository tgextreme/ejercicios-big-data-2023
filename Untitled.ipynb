# %%
import csv
import numpy as np

with open("centros-educativos_2019.csv", 'r', encoding="utf-8") as f:
    data =list(csv.reader(f,delimiter=";"))
data =np.array(data)
#print (data)# comprobamos que se han guardado los datos

for x in data:
    print('<iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q='+x[16]+ ","+x[15]+'&output=embed">')
# Out:
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=LATITUD,LONGITUD&output=embed">
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=39.145717,-0.332009&output=embed">
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=39.457914,-0.361562&output=embed">
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=39.012371,-0.467294&output=embed">
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=39.006054,-0.562738&output=embed">
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="800" height="500" src="https://google.com/maps?q=39.022378,-0.417594&output=embed">
# ...

# %%
import csv
import numpy as np

with open("centros-educativos_2019.csv", 'r', encoding="utf-8") as f:
    data =list(csv.reader(f,delimiter=";"))
data =np.array(data)
#print (data)# comprobamos que se han guardado los datos
privado=0
concertado=0
publico
for x in data:
    if x[]=="VALÈNCIA":
        y=y+1
print("Hay "+str(y)+" referencias a VALÈNCIA")
# Out:
# Hay 2109 referencias a VALÈNCIA

# %%
import csv
import numpy as np

with open("centros-educativos_2019.csv", 'r', encoding="utf-8") as f:
    data =list(csv.reader(f,delimiter=";"))
data =np.array(data)
#print (data)# comprobamos que se han guardado los datos
privado=0
concertado=0
publico=0
for x in data:
    if x[5]=="PÚB.":
        publico=publico+1
    if x[5]=="PRIV.":
        privado=privado+1
    if x[5]=="PRIV. CONC.":
        concertado=concertado+1
print("Hay "+str(publico)+" públicos "+ str(privado) +" privado "+str(concertado)+" concertado a VALÈNCIA")
# Out:
# Hay 2058 públicos 1219 privado 418 concertado a VALÈNCIA

# %%
import csv
import numpy as np

with open("centros-educativos_2019.csv", 'r', encoding="utf-8") as f:
    data =list(csv.reader(f,delimiter=";"))
data =np.array(data)
#print (data)# comprobamos que se han guardado los datos
educacion=0
for x in data:
    if x[1]=="COLEGIO DE EDUCACIÓN INFANTIL Y PRIMARIA":
        #print(x)
        educacion=educacion+1
    

print("El número total de colegios de educación infantil es "+str(musica))
# Out:
# [['CODIGO' 'DENOMINACION_GENERICA_ES' 'DENOMINACION_GENERICA_VAL' ...
#   'TITULARIDAD' 'CIF' 'COMARCA']
#  ['46036839' 'COLEGIO DE EDUCACIÓN INFANTIL Y PRIMARIA'
#   "COL·LEGI D'EDUCACIÓ INFANTIL I PRIMÀRIA" ... 'GENERALITAT VALENCIANA'
#   'S4600330G' 'LA RIBERA BAIXA']
#  ['46036840' 'CENTRO PRIVADO DE EDUCACIÓN INFANTIL DE PRIMER CICLO'
#   "CENTRE PRIVAT D'EDUCACIÓ INFANTIL DE PRIMER CICLE" ... '' ''
#   'VALÈNCIA']
#  ...
#  ['46014959' 'COLEGIO DE EDUCACIÓN INFANTIL Y PRIMARIA'
#   "COL·LEGI D'EDUCACIÓ INFANTIL I PRIMÀRIA" ... 'GENERALITAT VALENCIANA'
#   'Q9655680H' "L'HORTA NORD"]
#  ['46014984' 'COLEGIO DE EDUCACIÓN INFANTIL Y PRIMARIA'
#   "COL·LEGI D'EDUCACIÓ INFANTIL I PRIMÀRIA" ... 'GENERALITAT VALENCIANA'
#   'Q9655220C' 'EL CAMP DE TÚRIA']
#  ['46014066' 'INSTITUTO DE EDUCACIÓN SECUNDARIA'
#   "INSTITUT D'EDUCACIÓ SECUNDÀRIA" ... 'GENERALITAT VALENCIANA'
#   'Q9655380E' 'LA SERRANÍA']]
# ['46036839' 'COLEGIO DE EDUCACIÓN INFANTIL Y PRIMARIA'
# ...
